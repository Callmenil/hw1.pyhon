# %%
from typing import Union

class Coordinate:

    

    def __truediv__(self, other: "Coordinate"): # self / other
        if type(other) != Coordinate:
            raise TypeError("Both objects should be of same type")

        if self.dimension != other.dimension:
            raise ValueError("Both objects should have the same dimension")

        return Coordinate(tuple([self.coo[i] / other.coo[i] for i in range(self.dimension)]))

    def __floordiv__(self, other: "Coordinate"): # self // other
        if type(other) != Coordinate:
            raise TypeError("Both objects should be of same type")

        if self.dimension != other.dimension:
            raise ValueError("Both objects should have the same dimension")

        return Coordinate(tuple([self.coo[i] // other.coo[i] for i in range(self.dimension)]))

    def __mod__(self, other: "Coordinate"): # self % other
        if type(other) != Coordinate:
            raise TypeError("Both objects should be of same type")

        if self.dimension != other.dimension:
            raise ValueError("Both objects should have the same dimension")

        return Coordinate(tuple([self.coo[i] % other.coo[i] for i in range(self.dimension)]))

    def __pow__(self, other: "Coordinate"): # self ** other
        if type(other) != Coordinate:
            raise TypeError("Both objects should be of same type")

        if self.dimension != other.dimension:
            raise ValueError("Both objects should have the same dimension")

        return Coordinate(tuple([self.coo[i] ** other.coo[i] for i in range(self.dimension)]))

    def __and__(self, other: "Coordinate"): # self & other
        if type(other) != Coordinate:
            raise TypeError("Both objects should be of same type")

        if self.dimension != other.dimension:
            raise ValueError("Both objects should have the same dimension")

        return Coordinate(tuple([self.coo[i] & other.coo[i] for i in range(self.dimension)]))

    def __or__(self, other: "Coordinate"): # self | other
        if type(other) != Coordinate:
            raise TypeError("Both objects should be of same type")

        if self.dimension != other.dimension:
            raise ValueError("Both objects should have the same dimension")

        return Coordinate(tuple([self.coo[i] | other.coo[i] for i in range(self.dimension)]))

    def __eq__(self, other: "Coordinate"): # self == other
        if type(other) != Coordinate:
            raise TypeError("Both objects should be of same type")

        return self.coo == other.coo

    def __ne__(self, other: "Coordinate"): # self != other
        if type(other) != Coordinate:
            raise TypeError("Both objects should be of same type")

        return self.coo != other.coo

    def __lt__(self, other: "Coordinate"): # self < other
        if type(other) != Coordinate:
            raise TypeError("Both objects should be of same type")

        return self.coo < other.coo

    def __le__(self, other: "Coordinate"): # self <= other
        if type(other) != Coordinate:
            raise TypeError("Both objects should be of same type")

        return self.coo <= other.coo

    def __gt__(self, other: "Coordinate"): # self > other
        if type(other) != Coordinate:
            raise TypeError("Both objects should be of same type")

        return self.coo > other.coo

    def __ge__(self, other: "Coordinate"): # self >= other
        if type(other) != Coordinate:
            raise TypeError("Both objects should be of same type")

        return self.coo >= other.coo

    def __getitem__(self, index: int): # object[index]
        if not (0 <= index < self.dimension):
            raise IndexError("Index out of range")
        return self.coo[index]
